# %% [markdown]
# # Showcase of Jupyter and EnOSlib integration (♥JupEnOS♥)
#
# Based on the example [Grid'5000 subnet reservation](https://discovery.gitlabpages.inria.fr/enoslib/tutorials/grid5000.html#subnet-reservation)

# %%
import logging
from pathlib import Path

import enoslib as en

logging.basicConfig(level=logging.INFO)

job_name = "♥JupEnOS♥"


prod_network = en.G5kNetworkConf(id="n1", type="prod", roles=["my_network"], site="rennes")
conf = (
    en.G5kConf.from_settings(job_name=job_name, job_type="allow_classic_ssh")
    .add_network_conf(prod_network)
    .add_network(
        id="not_linked_to_any_machine",
        type="slash_16",
        roles=["my_subnet"],
        site="rennes",
    )
    .add_machine(
        roles=["control"], cluster="paranoia", nodes=1, primary_network=prod_network
    )
    .finalize()
)

# %% [markdown]
# A quick look to the Configuration object

# %%
conf

# %% [markdown]
# Let's get the actual resources

# %%
roles, networks = provider.init()
# Out:
# INFO:enoslib.infra.enos_g5k.g5k_api_utils:Reloading ♥JupEnOS♥ from grenoble
# INFO:enoslib.infra.enos_g5k.g5k_api_utils:Reloading ♥JupEnOS♥ from lille
# INFO:enoslib.infra.enos_g5k.g5k_api_utils:Reloading ♥JupEnOS♥ from luxembourg
# INFO:enoslib.infra.enos_g5k.g5k_api_utils:Reloading ♥JupEnOS♥ from nancy
# INFO:enoslib.infra.enos_g5k.g5k_api_utils:Reloading ♥JupEnOS♥ from nantes
# INFO:enoslib.infra.enos_g5k.g5k_api_utils:Reloading ♥JupEnOS♥ from rennes
# INFO:enoslib.infra.enos_g5k.g5k_api_utils:Reloading 1702126 from rennes
# INFO:enoslib.infra.enos_g5k.g5k_api_utils:Reloading ♥JupEnOS♥ from sophia
# INFO:enoslib.infra.enos_g5k.g5k_api_utils:Waiting for 1702126 on rennes [2021-07-02 20:19:41]
# INFO:enoslib.infra.enos_g5k.g5k_api_utils:All jobs are Running !

# %% [markdown]
# ## Exploring your actual roles
#
# Looking at the roles, you can get some initial info about how the actual machines have been grouped together.
#
# Exploring the nested structure allows you to get some of the initial information about the resources.

# %%
roles
# Out:
# {'control': [Host(address='paranoia-3.rennes.grid5000.fr', alias='paranoia-3.rennes.grid5000.fr', user='root', keyfile=None, port=None, extra={}, net_devices=set())]}

# %% [markdown]
# ## This can be done for networks too !
#
# Networks are grouped by role names.
#
#
# In G5k specific case an IPv4 network may have an IPv6 companion. This is the case for the production network and both will be returned as usable for your experiment.
#
# You can also observed that a /16 on G5k is made of plenty /22 networks from which a pool of IPs/Macs is availabel for your experiment.

# %%
networks
# Out:
# WARNING:enoslib.infra.enos_g5k.objects:gateway is not yet implemented for <class 'enoslib.infra.enos_g5k.objects.G5kEnosProd6Network'> on the G5k side
# {'my_network': [<enoslib.infra.enos_g5k.objects.G5kEnosProd4Network object at 0x7f5ef370c990>, <enoslib.infra.enos_g5k.objects.G5kEnosProd6Network object at 0x7f5ef40c2350>], 'my_subnet': [<enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef40be150>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef3730690>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef3730d50>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef3727490>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef3727550>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef3727e50>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef3727e10>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef3727dd0>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef3727d90>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef3727890>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef3727c50>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef3727ad0>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef3727610>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef3708ad0>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef3708dd0>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef417ecd0>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef4176b10>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef4176590>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef3f73cd0>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef3f73490>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef3f73910>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef3f73c90>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef3f6b050>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef3f6bc10>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef3f6bc50>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef3f6b410>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef3f6b7d0>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef41308d0>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef4130750>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef41305d0>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef4130110>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef4130390>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef4130250>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef4130890>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef4130a50>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef4130b90>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef4130cd0>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef4130e10>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef4130f50>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef40d90d0>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef40d9210>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef40d9350>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef40d9490>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef40d95d0>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef40d9710>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef40d9850>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwork object at 0x7f5ef40d9990>, <enoslib.infra.enos_g5k.objects.G5kEnosSubnetNetwor ...

# %% [markdown]
# ## Roles can be synced to get more information
#
# The rationale behind syncing the node information includes:
# - getting contextualized network information for each node
# - getting hardware information (e.g. cpu counts)
# - (get in touch if you need extra information in here :) )

# %%
roles = en.sync_info(roles, networks)
# Out:
# [WARNING]: No inventory was parsed, only implicit localhost is available
# PLAY [all] *********************************************************************
#
# TASK [hostname] ****************************************************************
# changed: [paranoia-3.rennes.grid5000.fr]
#
# PLAY RECAP *********************************************************************
# paranoia-3.rennes.grid5000.fr : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
#
#
# PLAY [Gather facts for all hosts] **********************************************
#
# TASK [Gathering Facts] *********************************************************
# [DEPRECATION WARNING]: Distribution debian 10.9 on host
# paranoia-3.rennes.grid5000.fr should use /usr/bin/python3, but is using
# /usr/bin/python for backward compatibility with prior Ansible releases. A
# future Ansible release will default to using the discovered platform python for
#  this host. See https://docs.ansible.com/ansible/2.10/reference_appendices/inte
# rpreter_discovery.html for more information. This feature will be removed in
# version 2.12. Deprecation warnings can be disabled by setting
# deprecation_warnings=False in ansible.cfg.
# ok: [paranoia-3.rennes.grid5000.fr]
#
# TASK [setup] *******************************************************************
# ok: [paranoia-3.rennes.grid5000.fr]
#
# PLAY [Utils functions] *********************************************************
#
# TASK [Gathering Facts] *********************************************************
# ok: [paranoia-3.rennes.grid5000.fr]
#
# TASK [utils : include] *********************************************************
# included: /home/msimonin/workspace/repos/enoslib/enoslib/ansible/roles/utils/tasks/check_network.yml for paranoia-3.rennes.grid5000.fr
#
# TASK [utils : Dump network information in a file] ******************************
# changed: [paranoia-3.rennes.grid5000.fr]
#
# TASK [utils : Create the fake interfaces] **************************************
# skipping: [paranoia-3.rennes.grid5000.fr]
#
# PLAY RECAP *********************************************************************
# paranoia-3.rennes.grid5000.fr : ok=5    changed=1    unreachable=0    failed=0    skipped=1    rescued=0    ignored=0

# %%
roles
# Out:
# {'control': [Host(address='paranoia-3.rennes.grid5000.fr', alias='paranoia-3.rennes.grid5000.fr', user='root', keyfile=None, port=None, extra={}, net_devices={NetDevice(name='eno2', addresses=set()), NetDevice(name='enp3s0f0', addresses=set()), NetDevice(name='lo', addresses={IPAddress(network=None, ip=IPv6Interface('::1/128')), IPAddress(network=None, ip=IPv4Interface('127.0.0.1/8'))}), NetDevice(name='enp3s0f1', addresses=set()), NetDevice(name='eno1', addresses=set()), BridgeDevice(name='br0', addresses={IPAddress(network=<enoslib.infra.enos_g5k.objects.G5kEnosProd4Network object at 0x7f5ef370c990>, ip=IPv4Interface('172.16.100.3/20')), IPAddress(network=None, ip=IPv6Interface('fe80::a236:9fff:fe28:a6d4/64'))}, bridged=['enp3s0f0'])})]}

# %% [markdown]
# ### Of course don't forget to release your machines

# %%
provider.destroy()
# Out:
# INFO:enoslib.infra.enos_g5k.g5k_api_utils:Reloading ♥JupEnOS♥ from grenoble
# INFO:enoslib.infra.enos_g5k.g5k_api_utils:Reloading ♥JupEnOS♥ from lille
# INFO:enoslib.infra.enos_g5k.g5k_api_utils:Reloading ♥JupEnOS♥ from luxembourg
# INFO:enoslib.infra.enos_g5k.g5k_api_utils:Reloading ♥JupEnOS♥ from nancy
# INFO:enoslib.infra.enos_g5k.g5k_api_utils:Reloading ♥JupEnOS♥ from nantes
# INFO:enoslib.infra.enos_g5k.g5k_api_utils:Reloading ♥JupEnOS♥ from rennes
# INFO:enoslib.infra.enos_g5k.g5k_api_utils:Reloading 1702126 from rennes
# INFO:enoslib.infra.enos_g5k.g5k_api_utils:Reloading ♥JupEnOS♥ from sophia
# INFO:enoslib.infra.enos_g5k.g5k_api_utils:Killing the job (rennes, 1702126)
